# %% [markdown]
# # Stock Prediction Model Training (LSTM & XGBoost) in Google Colab
# This notebook allows you to train and evaluate the stock prediction models from the project using Google Colab's high-performance GPUs.
#
# ### Instructions
# 1. Upload the entire `colab_export` folder to your Google Drive.
# 2. Open this notebook in Google Colab.
# 3. Mount your Google Drive by running the cell below.
# 4. Change the directory to where you uploaded the files.
# 5. Run the installation and training cells.

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Navigate to the uploaded folder
# CHANGE THIS PATH to the location where you uploaded `colab_export` in your Drive.
# Example: %cd /content/drive/MyDrive/colab_export
# %cd /content/drive/MyDrive/colab_export

# %%
# 3. Install requirements
# !pip install -r requirements.txt

# %%
# 4. Run the model training script
# You can change the --ticker to any valid stock ticker like MSFT, GOOG, TSLA
# !python train_model.py --ticker AAPL --epochs 30 --lookback 60
